# %%
import numpy as np
import pandas as pd
import gzip
import csv
import json
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# Goal: Cut down the data on listings to work with less data

# %%
#Detailed listings for Nevada until December 31, 2019

df = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone2\\thedata\\listings_detailed.csv.gz')
df
# Out:
# E:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             id                            listing_url       scrape_id  \
# 0         3979      https://www.airbnb.com/rooms/3979  20190625152947
# 1        31388     https://www.airbnb.com/rooms/31388  20190625152947
# 2        44495     https://www.airbnb.com/rooms/44495  20190625152947
# 3        44701     https://www.airbnb.com/rooms/44701  20190625152947
# 4        97632     https://www.airbnb.com/rooms/97632  20190625152947
# ...        ...                                    ...             ...
# 9364  36041145  https://www.airbnb.com/rooms/36041145  20190625152947
# 9365  36041942  https://www.airbnb.com/rooms/36041942  20190625152947
# 9366  36041969  https://www.airbnb.com/rooms/36041969  20190625152947
# ...

# %%
# pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
df
# Out:
#             id                            listing_url       scrape_id  \
# 0         3979      https://www.airbnb.com/rooms/3979  20190625152947
# 1        31388     https://www.airbnb.com/rooms/31388  20190625152947
# 2        44495     https://www.airbnb.com/rooms/44495  20190625152947
# 3        44701     https://www.airbnb.com/rooms/44701  20190625152947
# 4        97632     https://www.airbnb.com/rooms/97632  20190625152947
# ...        ...                                    ...             ...
# 9364  36041145  https://www.airbnb.com/rooms/36041145  20190625152947
# 9365  36041942  https://www.airbnb.com/rooms/36041942  20190625152947
# 9366  36041969  https://www.airbnb.com/rooms/36041969  20190625152947
# 9367  36042868  https://www.airbnb.com/rooms/36042868  20190625152947
# 9368  36043096  https://www.airbnb.com/rooms/36043096  20190625152947
#
#      last_scraped                                               name  \
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9369 entries, 0 to 9368
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(25), int64(21), object(60)
# memory usage: 7.6+ MB

# %%
df.isnull()
# Out:
#          id  listing_url  scrape_id  last_scraped   name  summary  space  \
# 0     False        False      False         False  False    False  False
# 1     False        False      False         False  False    False  False
# 2     False        False      False         False  False    False  False
# 3     False        False      False         False  False    False  False
# 4     False        False      False         False  False    False  False
# ...     ...          ...        ...           ...    ...      ...    ...
# 9364  False        False      False         False  False     True   True
# 9365  False        False      False         False  False    False  False
# 9366  False        False      False         False  False    False  False
# 9367  False        False      False         False  False    False  False
# 9368  False        False      False         False  False    False   True
#
#       description  experiences_offered  neighborhood_overview  ...  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9369, step=1)

# %%
df.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  9.369000e+03  9.369000e+03            0.0         0.0             0.0
# mean   2.444241e+07  2.019063e+13            NaN         NaN             NaN
# std    8.790449e+06  0.000000e+00            NaN         NaN             NaN
# min    3.979000e+03  2.019063e+13            NaN         NaN             NaN
# 25%    1.905364e+07  2.019063e+13            NaN         NaN             NaN
# 50%    2.630046e+07  2.019063e+13            NaN         NaN             NaN
# 75%    3.150660e+07  2.019063e+13            NaN         NaN             NaN
# max    3.604310e+07  2.019063e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  9.369000e+03                   0.0          9361.000000
# mean   9.632479e+07                   NaN           102.147741
# std    7.915491e+07                   NaN           312.301984
# ...

# %%
df.head(10)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0    3979    https://www.airbnb.com/rooms/3979  20190625152947   2019-06-25
# 1   31388   https://www.airbnb.com/rooms/31388  20190625152947   2019-06-25
# 2   44495   https://www.airbnb.com/rooms/44495  20190625152947   2019-06-25
# 3   44701   https://www.airbnb.com/rooms/44701  20190625152947   2019-06-25
# 4   97632   https://www.airbnb.com/rooms/97632  20190625152947   2019-06-25
# 5  113019  https://www.airbnb.com/rooms/113019  20190625152947   2019-06-25
# 6  114140  https://www.airbnb.com/rooms/114140  20190625152947   2019-06-25
# 7  137104  https://www.airbnb.com/rooms/137104  20190625152947   2019-06-25
# 8  143096  https://www.airbnb.com/rooms/143096  20190625152947   2019-06-25
# 9  161848  https://www.airbnb.com/rooms/161848  20190625152947   2019-06-25
#
#                                                name  \
# 0                    Chan's House: Up to 4 Bedrooms
# ...

# %%
#Copying our original dataframe
newlist = df.copy()

# %%
#checking csv file to drop columns
newlist.to_csv('peeklistings.csv')

# %%
#Dropping irrevelant columns 
newlist1 = newlist.drop(['experiences_offered', 'monthly_price', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 
'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_90', 'availability_365'], axis=1)
newlist1
# Out:
#             id                            listing_url       scrape_id  \
# 0         3979      https://www.airbnb.com/rooms/3979  20190625152947
# 1        31388     https://www.airbnb.com/rooms/31388  20190625152947
# 2        44495     https://www.airbnb.com/rooms/44495  20190625152947
# 3        44701     https://www.airbnb.com/rooms/44701  20190625152947
# 4        97632     https://www.airbnb.com/rooms/97632  20190625152947
# ...        ...                                    ...             ...
# 9364  36041145  https://www.airbnb.com/rooms/36041145  20190625152947
# 9365  36041942  https://www.airbnb.com/rooms/36041942  20190625152947
# 9366  36041969  https://www.airbnb.com/rooms/36041969  20190625152947
# 9367  36042868  https://www.airbnb.com/rooms/36042868  20190625152947
# 9368  36043096  https://www.airbnb.com/rooms/36043096  20190625152947
#
#      last_scraped                                               name  \
# ...

# %%
#checking csv file to drop columns
newlist1.to_csv('peeklistings1.csv')

# %%
#Dropping irrevelant columns 
newlist2 = newlist1.drop(['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate', 'host_neighbourhood',
'host_listings_count', 'host_total_listings_count', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy'], axis=1)
newlist2
# Out:
#             id                            listing_url       scrape_id  \
# 0         3979      https://www.airbnb.com/rooms/3979  20190625152947
# 1        31388     https://www.airbnb.com/rooms/31388  20190625152947
# 2        44495     https://www.airbnb.com/rooms/44495  20190625152947
# 3        44701     https://www.airbnb.com/rooms/44701  20190625152947
# 4        97632     https://www.airbnb.com/rooms/97632  20190625152947
# ...        ...                                    ...             ...
# 9364  36041145  https://www.airbnb.com/rooms/36041145  20190625152947
# 9365  36041942  https://www.airbnb.com/rooms/36041942  20190625152947
# 9366  36041969  https://www.airbnb.com/rooms/36041969  20190625152947
# 9367  36042868  https://www.airbnb.com/rooms/36042868  20190625152947
# 9368  36043096  https://www.airbnb.com/rooms/36043096  20190625152947
#
#      last_scraped                                               name  \
# ...

# %%
#checking csv file to drop columns
newlist2.to_csv('peeklistings2.csv')

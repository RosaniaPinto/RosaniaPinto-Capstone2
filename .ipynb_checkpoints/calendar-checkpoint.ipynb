# %%
import numpy as np
import pandas as pd
import gzip
import csv
import json
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#Detailed calendar data for Nevada until December 31, 2019
#look at calendar to see if its avablity or not and if its true or not 

df = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone2\\thedata\\calendar_detailed.csv.gz')
df
# Out:
#          listing_id        date available    price adjusted_price  \
# 0              3979  2019-06-25         f   $60.00         $60.00
# 1              3979  2019-06-26         f   $60.00         $60.00
# 2              3979  2019-06-27         f   $60.00         $60.00
# 3              3979  2019-06-28         f   $60.00         $60.00
# 4              3979  2019-06-29         f   $60.00         $60.00
# ...             ...         ...       ...      ...            ...
# 3419680    35798130  2020-06-19         t  $350.00        $350.00
# 3419681    35798130  2020-06-20         t  $350.00        $350.00
# 3419682    35798130  2020-06-21         t  $300.00        $300.00
# 3419683    35798130  2020-06-22         t  $300.00        $300.00
# 3419684    35798130  2020-06-23         t  $300.00        $300.00
#
#          minimum_nights  maximum_nights
# 0                     1             365
# 1                     1             365
# 2                     1             365
# ...

# %%
df.shape
# Out:
# (3419685, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419685 entries, 0 to 3419684
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 182.6+ MB

# %%
df.dtypes
# Out:
# listing_id         int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights     int64
# maximum_nights     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price', 'adjusted_price',
#        'minimum_nights', 'maximum_nights'],
#       dtype='object')

# %%
# Copying our original dataframe
cad = df.copy()

# %% [markdown]
# Filtering it out for 2019 data

# %%
cad.dtypes
# Out:
# listing_id         int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights     int64
# maximum_nights     int64
# dtype: object

# %%
cad.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        3979  2019-06-25         f  $60.00         $60.00               1
# 1        3979  2019-06-26         f  $60.00         $60.00               1
# 2        3979  2019-06-27         f  $60.00         $60.00               1
# 3        3979  2019-06-28         f  $60.00         $60.00               1
# 4        3979  2019-06-29         f  $60.00         $60.00               1
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
cad.sort_values('date')
# Out:
#          listing_id        date available      price adjusted_price  \
# 0              3979  2019-06-25         f     $60.00         $60.00
# 1760518    26716722  2019-06-25         f     $75.00         $75.00
# 1760340    26639200  2019-06-25         f     $45.00         $45.00
# 1759527    26623866  2019-06-25         f    $144.00        $144.00
# 1759190    26715622  2019-06-25         t  $1,618.00      $1,618.00
# ...             ...         ...       ...        ...            ...
# 1001686    20833182  2020-06-23         f     $70.00         $70.00
# 592128     16150259  2020-06-23         f    $185.00        $185.00
# 1723151    25882380  2020-06-23         f    $299.00        $299.00
# 2997785    34147725  2020-06-23         f     $42.00         $42.00
# 3419684    35798130  2020-06-23         t    $300.00        $300.00
#
#          minimum_nights  maximum_nights
# 0                     1             365
# 1760518               5               7
# ...

# %%
print(cad.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419685 entries, 0 to 3419684
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 182.6+ MB
# None

# %%
cad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419685 entries, 0 to 3419684
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 182.6+ MB

# %%
#making a year column

# %%
cad[['year', 'month', "date"]] = cad['date'].str.rsplit(",",2, expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-037bd9866fc5> in <module>
# ----> 1 cad[['year', 'month', "date"]] = cad['date'].str.rsplit(",",2, expand=True)
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
# ...

# %%
cad[['year', 'month', "date"]] = cad['date'].str.rsplit(expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d7fd6674e8e0> in <module>
# ----> 1 cad[['year', 'month', "date"]] = cad['date'].str.rsplit(expand=True)
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
# ...

# %%
cad[['year', 'month', "date"]] = cad['date'].str.rsplit(n=1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-ff986ca393f6> in <module>
# ----> 1 cad[['year', 'month', "date"]] = cad['date'].str.rsplit(n=1, expand=True)
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
# ...

# %%
cad[['year', 'month', "date"]] = cad['date'].str.split('/', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-a5b084c7444b> in <module>
# ----> 1 cad[['year', 'month', "date"]] = cad['date'].str.split('/', expand=True)
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
# ...

# %%
cad = cad.set_index('date')
df2 = df['detail_EOBs'].str.split(expand=True)
df.join(df2)

# %%
cad[['year', 'month', "date"]] = cad['date'].str.split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-e5adf99906b7> in <module>
# ----> 1 cad[['year', 'month', "date"]] = cad['date'].str.split()
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2964             else:
#    2965                 indexer = self.loc._get_listlike_indexer(
# -> 2966                     key, axis=1, raise_missing=False
#    2967                 )[1]
#    2968                 self._check_setitem_copy()
#
# ...

# %%
cad.query('date.str.contains("2019")', engine='python')
# Out:
#          listing_id        date available    price adjusted_price  \
# 0              3979  2019-06-25         f   $60.00         $60.00
# 1              3979  2019-06-26         f   $60.00         $60.00
# 2              3979  2019-06-27         f   $60.00         $60.00
# 3              3979  2019-06-28         f   $60.00         $60.00
# 4              3979  2019-06-29         f   $60.00         $60.00
# ...             ...         ...       ...      ...            ...
# 3419505    35798130  2019-12-27         t  $350.00        $350.00
# 3419506    35798130  2019-12-28         t  $350.00        $350.00
# 3419507    35798130  2019-12-29         t  $300.00        $300.00
# 3419508    35798130  2019-12-30         t  $300.00        $300.00
# 3419509    35798130  2019-12-31         t  $300.00        $300.00
#
#          minimum_nights  maximum_nights
# 0                     1             365
# 1                     1             365
# 2                     1             365
# ...

# %%
cad.query('date.str.contains("2019")', engine='python')

# %%
new2019cad = cad.query('date.str.contains("2019")', engine='python')

# %%
new2019cad
# Out:
#          listing_id        date available    price adjusted_price  \
# 0              3979  2019-06-25         f   $60.00         $60.00
# 1              3979  2019-06-26         f   $60.00         $60.00
# 2              3979  2019-06-27         f   $60.00         $60.00
# 3              3979  2019-06-28         f   $60.00         $60.00
# 4              3979  2019-06-29         f   $60.00         $60.00
# ...             ...         ...       ...      ...            ...
# 3419505    35798130  2019-12-27         t  $350.00        $350.00
# 3419506    35798130  2019-12-28         t  $350.00        $350.00
# 3419507    35798130  2019-12-29         t  $300.00        $300.00
# 3419508    35798130  2019-12-30         t  $300.00        $300.00
# 3419509    35798130  2019-12-31         t  $300.00        $300.00
#
#          minimum_nights  maximum_nights
# 0                     1             365
# 1                     1             365
# 2                     1             365
# ...

# %%
cad['date']=='2019'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3419680    False
# 3419681    False
# 3419682    False
# 3419683    False
# 3419684    False
# Name: date, Length: 3419685, dtype: bool

# %%
date = cad['date']
date = date.str.strip()
date = date.str.rsplit(' ',2,expand=True)
date.head()
date = date.rename(columns={0:'address',1:'state',2:'zipcode'})

# %%
year.head()
address = address.rename(columns={0:'address',1:'state',2:'zipcode'})
address

# %% [markdown]
# Don't run below yet it was a test on datetime function

# %%
cad['date'] = pd.to_datetime(cad.date)

# %%
cad[(cad['date']>=datetime.datetime(2019,1,1))]
# Out:
#          listing_id       date available    price adjusted_price  \
# 0           2234029 2019-12-31         f  $140.00        $140.00
# 1            948041 2019-12-31         f   $60.00         $60.00
# 2            948041 2020-01-01         f   $65.00         $65.00
# 3            948041 2020-01-02         f   $65.00         $65.00
# 4            948041 2020-01-03         f   $65.00         $65.00
# ...             ...        ...       ...      ...            ...
# 3977035    39896044 2020-12-25         f   $58.00         $58.00
# 3977036    39896044 2020-12-26         f   $58.00         $58.00
# 3977037    39896044 2020-12-27         f   $58.00         $58.00
# 3977038    39896044 2020-12-28         f   $58.00         $58.00
# 3977039    39896044 2020-12-29         f   $58.00         $58.00
#
#          minimum_nights  maximum_nights
# 0                    30            1125
# 1                    31            1096
# 2                    31            1096
# ...
